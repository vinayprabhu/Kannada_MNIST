# %%
x_dig=np.load('X_kannada_MNIST_train.npz')
print(x_dig.files)
xx=x_dig['arr_0']
xx.shape
# Out:
# ['arr_0']
# (60000, 28, 28)

# %%
# %matplotlib inline
for i in range(100):
    plt.subplot(10,10,i+1)
    plt.imshow(xx[i],cmap='gray')
    plt.axis('Off')

# %%
# !pip install liac-arff
# Out:
# ...
#   Running setup.py bdist_wheel for liac-arff: started
#   Running setup.py bdist_wheel for liac-arff: finished with status 'done'
#   Stored in directory: C:\Users\vinay\AppData\Local\pip\Cache\wheels\d1\6a\e7\529dc54d76ecede4346164a09ae3168df358945612710f5203
# Successfully built liac-arff
# ...
# You are using pip version 18.1, however version 19.2.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import arff, numpy as np
dataset = arff.load(open('mydataset.arff', 'rb'))
data = np.array(dataset['data'])

# %%
import arff
